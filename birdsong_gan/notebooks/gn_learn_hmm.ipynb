# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gaussian_hmm import GaussHMM

# %%
from hmm import HMM, hmm_opts
import gc

# %%
from utils.utils import rescale_spectrogram

# %%
import matplotlib.pyplot as plt

# %%
datapath = '/home/gagan/data/zudeep/bird_hdfs/b3g20'
netEpath = '/home/gagan/data/zudeep/models/nz_12_residual/2021-05-05_10-41-37.547480/netE_epoch_6.pth'
netGpath = '/home/gagan/data/zudeep/models/nz_12_residual/2021-05-05_10-41-37.547480/netG_epoch_6.pth'

# %%
hmm_opts
# Out:
# {'hidden_state_size': [5, 10, 15, 20, 30, 50, 75, 100],
#  'covariance_type': 'spherical',
#  'fit_params': 'stmc',
#  'transmat_prior': 1.0,
#  'n_iter': 300,
#  'tolerance': 0.01,
#  'nz': 16,
#  'ngf': 264,
#  'nc': 1,
#  'covars_prior': 1.0,
#  'init_params': 'stmc',
#  'imageH': 129,
#  'imageW': 16,
#  'noverlap': 0,
#  'batchsize': 2,
#  'train_proportion': 0.7,
#  'nsamplesteps': 128,
#  'nsamps': 10,
#  'sample_var': 0.0,
#  'sample_invtemperature': 1.0,
#  'munge': False,
#  'munge_len': 50,
#  'n_restarts': 1,
#  'do_chaining': False,
#  'min_seq_multiplier': 10,
#  'cuda': True,
#  'hmm_random_state': 0,
#  'last_day': -1,
#  'start_from': 0,
#  'datapath': '',
#  'netEpath': '',
#  'netGpath': '',
#  'outpath': '',
#  'resnet': False,
#  'save_output': True,
#  'get_audio': False}

# %%
hmm_opts['fit_params'] = 'stmc'

hmm_opts['save_output'] = False
hmm_opts['n_restarts'] = 1

hmm_opts['nz'] = 12
hmm_opts['ngf'] = 128
hmm_opts['resnet'] = True


hmm_opts['covars_prior'] = 1.2
hmm_opts['transmat_prior'] = 1.5

hmm_opts['covariance_type'] = 'diag'

hmm_opts['init_params'] = 'kmeans'
hmm_opts['munge'] = True
hmm_opts['munge_len'] = 40

hmm_opts['get_audio'] = False

# %%
hmm_ = HMM(datapath, netEpath=netEpath, netGpath=netGpath, hmm_opts=hmm_opts, save_output=False)
# Out:
# ...total number of folders = 89 ...

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
Z = hmm_.Z
len(Z)
# Out:
# 991

# %%
hmm_.Z = Z

# %%
res = hmm_.fit_single_day(30, hidden_size=50, lastmodel=None)
# Out:
# ..... day is 2016-03-20 .....
# ... available files: 3178 ...
# # learning hmm with 50 states #
# # computing model entropy #
# ...... computing Entropy ......
# ..... Transition entropy = 2.00, Emission entropy = -4.17 .....

# %%
hmm_.close()

# %%
model = res[0]
test_scores = res[1]
train_scores = res[2]
med_active = res[3]
std_active = res[4]
Ltrain = res[5]
Ltest = res[6]

# %%
test_scores
# Out:
# 42014.34662660179

# %%
plt.figure(figsize = (8,8))
plt.imshow(model.transmat_)

# %% [markdown]
# # reconstruction

# %%
from utils.utils import decode_by_batch, overlap_decode, overlap_encode

# %%
X = hmm_.dataset.get(day=20)

# %%
Znew = overlap_encode(X[1], hmm_.netE, transform_sample = False, imageW = 16, noverlap = 2,
                   cuda = True)

# %%
Znew = Znew.squeeze()
Znew.shape

# %%
Xnew, audio  = overlap_decode(Z, hmm_.netG, noverlap = 2, get_audio = False, cuda = True)

# %%
Xnew.shape

# %%
plt.figure(figsize=(12,6))
plt.imshow(rescale_spectrogram(Xnew), origin='lower', cmap='gray')

# %%
spect_out =

# %%
Z[0].shape

# %%
import torch

# %%
zhat = torch.from_numpy(Z[0][0]).float().view(1,16,1,1).cuda()
zhat.size()
# Out:
# torch.Size([1, 16, 1, 1])

# %%
out = hmm_.netG(zhat)

# %%
out.size()
# Out:
# torch.Size([1, 1, 129, 16])

# %%
len(X)
# Out:
# 2002

# %%
for l in range(10):
    plt.figure(figsize=(12,6))
    plt.imshow(spect_out[l], origin='lower', cmap='gray')
    #plt.imshow(rescale_spectrogram(X[l]),origin='lower', cmap='gray')

# %% [markdown]
# # generate spectrograms

# %%
hmm_.P
# Out:
# {'hidden_state_size': [5, 10, 15, 20, 30, 50, 75, 100],
#  'covariance_type': 'diag',
#  'fit_params': 'stmc',
#  'transmat_prior': 1.0,
#  'n_iter': 300,
#  'tolerance': 0.01,
#  'nz': 32,
#  'ngf': 96,
#  'nc': 1,
#  'covars_prior': 1.0,
#  'init_params': 'kmeans',
#  'imageH': 129,
#  'imageW': 16,
#  'noverlap': 0,
#  'batchsize': 2,
#  'train_proportion': 0.7,
#  'nsamplesteps': 48,
#  'nsamps': 10,
#  'sample_var': 0.0,
#  'sample_invtemperature': 1.0,
#  'munge_len': 50,
#  'n_restarts': 1,
#  'do_chaining': False,
#  'min_seq_multiplier': 10,
#  'cuda': True,
#  'hmm_random_state': 0,
#  'last_day': -1,
#  'start_from': 0,
#  'datapath': '',
#  'netEpath': '',
#  'netGpath': '',
#  'outpath': '',
#  'resnet': True,
#  'save_output': False,
#  'get_audio': False,
#  'munge': True}

# %%
#hmm_.P['sample_var'] = 0.1
#hmm_.P['fit_params'] = 'stm'

hmm_.P['nsamplesteps'] = 48
hmm_.P['sample_invtemperature'] = 1.

# %%
model.covars_.shape
# Out:
# (20, 1, 32, 32)

# %%
[model.covars_[k][0][0,0] for k in range(model.n_components)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-47bcf5f13b56> in <module>
# ----> 1 [model.covars_[k][0][0,0] for k in range(model.n_components)]
#
# <ipython-input-51-47bcf5f13b56> in <listcomp>(.0)
# ----> 1 [model.covars_[k][0][0,0] for k in range(model.n_components)]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
spect_out, audio_out = hmm_.generate_spectrogram_samples(model)

# %%
len(spect_out)
# Out:
# 10

# %%
for l in range(len(spect_out)):
    plt.figure(figsize=(15,12))
    plt.imshow(rescale_spectrogram(spect_out[l]), origin='lower', cmap='gray')

# %% [markdown]
# # own gaussian

# %%
import numpy as np

# %%
hmm2 = GaussHMM( K=30, D = 12, learn_params = 'stmc', startprob_prior_conc_weight = 1.2, transmat_prior_conc_weight = 1.5, mean_prior = 0., 
                 covar_prior_weight = 1.5, estimate_type = 'MAP', do_kmeans = True, n_iters = 100, tolerance = 1e-2, verbose = True)

# %%
type(Z)
# Out:
# list

# %%
Z[0].shape
# Out:
# (94, 12)

# %%
CC = np.cov(Z[0].T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-839a94eda2bd> in <module>
# ----> 1 CC = np.cov(Z[0].T)
#
# NameError: name 'np' is not defined

# %%
hmm2.fit(Z, log_every=1)
# Out:
# .....iteration 0, total log LL : -2037157.88746, change : -2037157.88746 .....
# .....iteration 1, total log LL : -333099.91249, change : 1704057.97498 .....
# .....iteration 2, total log LL : -6325.16060, change : 326774.75188 .....
# .....iteration 3, total log LL : 51679.40448, change : 58004.56508 .....
# .....iteration 4, total log LL : 102121.95386, change : 50442.54938 .....
# .....iteration 5, total log LL : 140104.35520, change : 37982.40135 .....
# .....iteration 6, total log LL : 171164.68946, change : 31060.33426 .....
# .....iteration 7, total log LL : 192656.47184, change : 21491.78238 .....
# .....iteration 8, total log LL : 214722.40134, change : 22065.92950 .....
# .....iteration 9, total log LL : 236872.39185, change : 22149.99051 .....
# .....iteration 10, total log LL : 253094.47316, change : 16222.08131 .....
# .....iteration 11, total log LL : 263336.18194, change : 10241.70878 .....
# .....iteration 12, total log LL : 271037.05351, change : 7700.87157 .....
# .....iteration 13, total log LL : 277149.18978, change : 6112.13627 .....
# .....iteration 14, total log LL : 282824.74714, change : 5675.55736 .....
# .....iteration 15, total log LL : 288094.33204, change : 5269.58490 .....
# .....iteration 16, total log LL : 291411.92167, change : 3317.58964 .....
# .....iteration 17, total log LL : 294297.15596, change : 2885.23429 .....
# .....iteration 18, total log LL : 297218.35496, change : 2921.19900 .....
# .....iteration 19, total log LL : 299369.20345, change : 2150.84848 .....
# .....iteration 20, total log LL : 300534.11079, change : 1164.90734 .....
# .....iteration 21, total log LL : 301341.90946, change : 807.79867 .....
# .....iteration 22, total log LL : 302030.93552, change : 689.02606 .....
# .....iteration 23, total log LL : 302779.36399, change : 748.42847 .....
# .....iteration 24, total log LL : 303721.96155, change : 942.59756 .....
# .....iteration 25, total log LL : 305142.36222, change : 1420.40067 .....
# .....iteration 26, total log LL : 307783.79005, change : 2641.42783 .....
# .....iteration 27, total log LL : 310682.18211, change : 2898.39205 .....
# .....iteration 28, total log LL : 312655.96241, change : 1973.78030 .....
# .....iteration 29, total log LL : 314518.63665, change : 1862.67424 .....
# .....iteration 30, total log LL : 317038.25323, change : 2519.61657 .....
# .....iteration 75, total log LL : 331079.95022, change : 17.97559 .....
# .....iteration 76, total log LL : 331101.55165, change : 21.60143 .....
# .....iteration 77, total log LL : 331128.61655, change : 27.06489 .....
# .....iteration 78, total log LL : 331163.06196, change : 34.44541 .....
# .....iteration 79, total log LL : 331205.83035, change : 42.76839 .....
# .....iteration 80, total log LL : 331255.46022, change : 49.62987 .....
# .....iteration 81, total log LL : 331307.82755, change : 52.36734 .....
# .....iteration 82, total log LL : 331358.38678, change : 50.55922 .....
# .....iteration 83, total log LL : 331405.00462, change : 46.61785 .....
# .....iteration 84, total log LL : 331447.79620, change : 42.79157 .....
# .....iteration 85, total log LL : 331487.59350, change : 39.79730 .....
# .....iteration 86, total log LL : 331525.16990, change : 37.57639 .....
# .....iteration 87, total log LL : 331561.15882, change : 35.98892 .....
# .....iteration 88, total log LL : 331596.16018, change : 35.00136 .....
# .....iteration 89, total log LL : 331630.46501, change : 34.30484 .....
# .....iteration 90, total log LL : 331663.02951, change : 32.56450 .....
# .....iteration 91, total log LL : 331693.66208, change : 30.63257 .....
# .....iteration 92, total log LL : 331724.15349, change : 30.49141 .....
# .....iteration 93, total log LL : 331756.30743, change : 32.15394 .....
# .....iteration 94, total log LL : 331789.87676, change : 33.56933 .....
# .....iteration 95, total log LL : 331822.88341, change : 33.00665 .....
# .....iteration 96, total log LL : 331853.40114, change : 30.51773 .....
# .....iteration 97, total log LL : 331880.02666, change : 26.62551 .....
# .....iteration 98, total log LL : 331902.05182, change : 22.02517 .....
# .....iteration 99, total log LL : 331919.66279, change : 17.61097 .....

# %%
h, zsamps = hmm2.sample(50)

# %%
zsamps.shape
# Out:
# (50, 12)

# %%
from utils.utils import overlap_decode, overlap_encode

# %%
samp_spects,_ = overlap_decode(zsamps, hmm_.netG,  noverlap = 0, cuda = True, get_audio = False)

# %%
samp_spects.shape
# Out:
# (129, 800)

# %%
plt.figure(figsize=(15,6))
plt.imshow(rescale_spectrogram(samp_spects), origin='lower', cmap='gray')
#plt.savefig('/home/gagan/data/zudeep/hmm_dump/r15y5_nz12/day_22_hiddensize_30/samples_model_with_gagan_code.eps',dpi=100,format='eps')
#plt.close()

# %%
import numpy as np

# %%
np.sum(np.any(hmm2.transmat == 0.0))
# Out:
# 0

# %%
plt.figure(figsize = (8,8))
plt.imshow(hmm2.transmat)

# %%
plt.plot(hmm2.startprob)

# %%
plt.figure(figsize = (8,8))
plt.imshow(hmm2.covs[4])

# %%
import joblib

# %%
joblib.dump({'model_hmmlearn': hmm_, 'model_gagan':hmm2, 'data': Z}, '/home/gagan/data/zudeep/hmm_dump/r15y5_nz12/day_22_hiddensize_30/model_with_gagan_code.pkl')
# Out:
# ['/home/gagan/data/zudeep/hmm_dump/r15y5_nz12/day_22_hiddensize_30/model_with_gagan_code.pkl']

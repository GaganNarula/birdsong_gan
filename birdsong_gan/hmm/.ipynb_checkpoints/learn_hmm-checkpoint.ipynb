# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gaussian_hmm import GaussHMM

# %%
from hmm import HMM
from hmm_opts import hmm_opts
import gc

# %%
from utils.utils import rescale_spectrogram

# %%
import matplotlib.pyplot as plt

# %%
datapath = '/home/gagan/data/zudeep/bird_hdfs/b7r16'
netEpath = '/home/gagan/data/zudeep/models/nz_16_layernorm/2020-02-12_15-54-45.559201/netE_epoch_3.pth'
netGpath = '/home/gagan/data/zudeep/models/nz_16_layernorm/2020-02-12_15-54-45.559201/netG_epoch_3.pth'

# %%
hmm_opts
# Out:
# {'hidden_state_size': [5, 10, 15, 20, 30, 50, 75, 100],
#  'covariance_type': 'spherical',
#  'fit_params': 'stmc',
#  'transmat_prior': 1.0,
#  'n_iter': 300,
#  'tolerance': 0.01,
#  'nz': 16,
#  'ngf': 264,
#  'nc': 1,
#  'covars_prior': 1.0,
#  'init_params': 'stmc',
#  'imageH': 129,
#  'imageW': 16,
#  'batchsize': 2,
#  'train_proportion': 0.7,
#  'nsamplesteps': 128,
#  'nsamps': 10,
#  'sample_var': 0.1,
#  'sample_invtemperature': 1.0,
#  'n_restarts': 10,
#  'do_chaining': False,
#  'min_seq_multiplier': 10,
#  'cuda': True,
#  'hmm_random_state': 0,
#  'last_day': -1,
#  'start_from': 0,
#  'datapath': '',
#  'netEpath': '',
#  'netGpath': '',
#  'outpath': '',
#  'save_output': True}

# %%
hmm_opts['save_output'] = False
hmm_opts['n_restarts'] = 1

hmm_opts['covars_prior'] = 1.
hmm_opts['transmat_prior'] = 1.

hmm_opts['covariance_type'] = 'spherical'

hmm_opts['init_params'] = 'kmeans'
hmm_opts['munge'] = True
hmm_opts['munge_len'] = 50

hmm_opts['get_audio'] = False

# %%
hmm_ = HMM(datapath, netEpath=netEpath, netGpath=netGpath, hmm_opts=hmm_opts, save_output=False)
# Out:
# ...total number of folders = 52 ...

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
Z = hmm_.Z
len(Z)
# Out:
# 529

# %%
hmm_.Z = Z

# %%
res = hmm_.fit_single_day(20, hidden_size=20, lastmodel=None)
# Out:
# ..... day is 2011-05-23 .....
# ... available files: 2002 ...
# # learning hmm with 20 states #
#          1     1212303.4232             +nan
#          2     1212303.4232          +0.0000
# # computing model entropy #
# ...... computing Entropy ......

# %%
hmm_.close()

# %%
model = res[0]
test_scores = res[1]
train_scores = res[2]
med_active = res[3]
std_active = res[4]
Ltrain = res[5]
Ltest = res[6]

# %%
test_scores
# Out:
# 977697.9091246706

# %%
plt.figure(figsize = (8,8))
plt.imshow(model.transmat_)

# %% [markdown]
# # reconstruction

# %%
from utils.utils import decode_by_batch, overlap_decode, overlap_encode

# %%
X = hmm_.dataset.get(day=20)
# Out:
# ..... day is 2011-05-23 .....
# ... available files: 2002 ...

# %%
Znew = overlap_encode(X[1], hmm_.netE, transform_sample = False, imageW = 16, noverlap = 2,
                   cuda = True)

# %%
Znew = Znew.squeeze()
Znew.shape
# Out:
# (254, 16)

# %%
Xnew, audio  = overlap_decode(Znew, hmm_.netG, noverlap = 2, get_audio = False, cuda = True)

# %%
Xnew.shape
# Out:
# (129, 269)

# %%
plt.figure(figsize=(12,6))
plt.imshow(rescale_spectrogram(Xnew), origin='lower', cmap='gray')

# %%
plt.figure(figsize=(12,6))
plt.imshow(rescale_spectrogram(X[1]), origin='lower', cmap='gray')

# %%
spect_out = [decode_by_batch(z, hmm_.netG,  batch_size = hmm_opts['batchsize'], \
                                 imageH=hmm_opts['imageH'], imageW=hmm_opts['imageW'], 
                                 cuda = hmm_opts['cuda'], get_audio = hmm_opts['get_audio'])[0] for z in Z]

# %%
Z[0].shape
# Out:
# (74, 16)

# %%
import torch

# %%
zhat = torch.from_numpy(Z[0][0]).float().view(1,16,1,1).cuda()
zhat.size()
# Out:
# torch.Size([1, 16, 1, 1])

# %%
out = hmm_.netG(zhat)

# %%
out.size()
# Out:
# torch.Size([1, 1, 129, 16])

# %%
len(X)
# Out:
# 2002

# %%
for l in range(10):
    plt.figure(figsize=(12,6))
    plt.imshow(spect_out[l], origin='lower', cmap='gray')
    #plt.imshow(rescale_spectrogram(X[l]),origin='lower', cmap='gray')
# Out:
# [autoreload of utils.utils failed: Traceback (most recent call last):
#   File "/home/gagan/anaconda3/envs/pytorch_gpu/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/gagan/anaconda3/envs/pytorch_gpu/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/gagan/anaconda3/envs/pytorch_gpu/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/gagan/anaconda3/envs/pytorch_gpu/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 916, in get_code
#   File "<frozen importlib._bootstrap_external>", line 846, in source_to_code
# ...

# %% [markdown]
# # generate spectrograms

# %%
hmm_.P = hmm_opts

# %%
hmm_.P['sample_var'] = 0.1
hmm_.P['nsamplesteps'] = 64
hmm_.P['fit_params'] = 'stm'

# %%
spect_out, audio_out = hmm_.generate_spectrogram_samples(model)

# %%
len(spect_out)
# Out:
# 10

# %%
for l in range(len(spect_out)):
    plt.figure(figsize=(12,6))
    plt.imshow(spect_out[l], origin='lower', cmap='gray')

# %%
hmm2 = GaussHMM( K=10, D = 16, learn_params = 'stmc', startprob_prior_conc_weight = 1.2, transmat_prior_conc_weight = 1.2, mean_prior = 0., 
                 covar_prior_weight = 1., estimate_type = 'MAP', do_kmeans = True, n_iters = 100, tolerance = 1e-2, verbose = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71a6c59af2dc> in <module>
# ----> 1 hmm2 = GaussHMM( K=10, D = 16, learn_params = 'stmc', startprob_prior_conc_weight = 1.2, transmat_prior_conc_weight = 1.2, mean_prior = 0.,
#       2                  covar_prior_weight = 1., estimate_type = 'MAP', do_kmeans = True, n_iters = 100, tolerance = 1e-2, verbose = True)
#
# NameError: name 'GaussHMM' is not defined

# %%
hmm2.fit(Z_munged, log_every=1)
# Out:
# .....iteration 0, total log LL : -2513625.92524, change : -2513625.92524 .....
# .....iteration 1, total log LL : nan, change : nan .....
# --Return--
# None
# > /home/gagan/code/birdsong_gan/birdsong_gan/hmm/gaussian_hmm.py(70)logGausspdf()
#      68             return p
#      69         except:
# ---> 70             pdb.set_trace()
#      71
#      72     def get_emission_logprobs(self, x):
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-50-29e3ccdc51e1> in <module>
# ----> 1 hmm2.fit(Z_munged, log_every=1)
#
# ~/code/birdsong_gan/birdsong_gan/hmm/gaussian_hmm.py in fit(self, seqs, log_every)
#     218                 # sigma is [T,nstates,nstates] matrix
#     219                 # gamma is [T, nstates] matrix
# --> 220                 _, _, gamma, sigma, c = self.E_step(y)
#     221                 LL += np.log(c).sum()
# ...
